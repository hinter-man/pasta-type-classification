# %% [markdown]
# # Pasta Type Image Classification
#
# the following pasta types will be classified:
# - spaghetti
# - rotini
# - penne
# - gnocchi

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# alembic                       1.4.3
# argon2-cffi                   20.1.0
# async-generator               1.10
# attrs                         20.2.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.1
# beautifulsoup4                4.9.3
# bleach                        3.2.1
# blinker                       1.4
# bokeh                         2.2.3
# Bottleneck                    1.3.2
# brotlipy                      0.7.0
# certifi                       2020.6.20
# certipy                       0.1.3
# cffi                          1.14.3
# chardet                       3.0.4
# click                         7.1.2
# cloudpickle                   1.6.0
# conda                         4.9.0
# conda-package-handling        1.7.2
# cryptography                  3.2.1
# cycler                        0.10.0
# Cython                        0.29.21
# cytoolz                       0.11.0
# dask                          2.30.0
# decorator                     4.4.2
# defusedxml                    0.6.0
# dill                          0.3.3
# distributed                   2.30.1
# entrypoints                   0.3
# fastcache                     1.1.0
# fsspec                        0.8.4
# gmpy2                         2.1.0b1
# h5py                          2.10.0
# HeapDict                      1.0.1
# idna                          2.10
# imagecodecs                   2020.5.30
# imageio                       2.9.0
# importlib-metadata            2.0.0
# ipykernel                     5.3.4
# ipympl                        0.5.8
# ipython                       7.19.0
# ipython-genutils              0.2.0
# ipywidgets                    7.5.1
# jedi                          0.17.2
# Jinja2                        2.11.2
# joblib                        0.17.0
# json5                         0.9.5
# jsonschema                    3.2.0
# jupyter-client                6.1.7
# jupyter-core                  4.6.3
# jupyter-telemetry             0.0.5
# jupyterhub                    1.2.1
# jupyterlab                    2.2.9
# jupyterlab-pygments           0.1.2
# jupyterlab-server             1.2.0
# kiwisolver                    1.3.1
# llvmlite                      0.34.0
# locket                        0.2.0
# Mako                          1.1.3
# MarkupSafe                    1.1.1
# matplotlib                    3.3.2
# mistune                       0.8.4
# mock                          4.0.2
# mpmath                        1.1.0
# msgpack                       1.0.0
# nbclient                      0.5.1
# nbconvert                     6.0.7
# nbformat                      5.0.8
# nest-asyncio                  1.4.2
# networkx                      2.5
# notebook                      6.1.4
# numba                         0.51.2
# numexpr                       2.7.1
# numpy                         1.19.4
# oauthlib                      3.0.1
# olefile                       0.46
# packaging                     20.4
# pamela                        1.0.0
# pandas                        1.1.4
# pandocfilters                 1.4.2
# parso                         0.7.1
# partd                         1.1.0
# patsy                         0.5.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.0.1
# pip                           20.2.4
# prometheus-client             0.8.0
# prompt-toolkit                3.0.8
# protobuf                      3.13.0
# psutil                        5.7.3
# ptyprocess                    0.6.0
# pycosat                       0.6.3
# pycparser                     2.20
# pycurl                        7.43.0.6
# Pygments                      2.7.2
# PyJWT                         1.7.1
# pyOpenSSL                     19.1.0
# pyparsing                     2.4.7
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# python-dateutil               2.8.1
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2020.4
# PyWavelets                    1.1.1
# PyYAML                        5.3.1
# pyzmq                         19.0.2
# requests                      2.24.0
# ruamel-yaml-conda             0.15.80
# ruamel.yaml                   0.16.12
# ruamel.yaml.clib              0.2.2
# scikit-image                  0.17.2
# scikit-learn                  0.23.2
# scipy                         1.5.3
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-linux_x86_64.whl size=81740 sha256=3033a57488d537d6b8801019f609608810ab1615dd595a6eae8b18b75769eddc
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5f/fd/9e/b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built termcolor wrapt
# Installing collected packages: requests-oauthlib, pyasn1, rsa, cachetools, pyasn1-modules, google-auth, google-auth-oauthlib, grpcio, markdown, tensorboard-plugin-wit, werkzeug, numpy, absl-py, tensorboard, google-pasta, gast, termcolor, astunparse, tensorflow-estimator, opt-einsum, keras-preprocessing, wrapt, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.4
#     Uninstalling numpy-1.19.4:
#       Successfully uninstalled numpy-1.19.4
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 cachetools-4.1.1 gast-0.3.3 google-auth-1.23.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.33.2 keras-preprocessing-1.1.2 markdown-3.3.3 numpy-1.18.5 opt-einsum-3.3.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.6 tensorboard-2.3.0 tensorboard-plugin-wit-1.7.0 tensorflow-2.3.1 tensorflow-estimator-2.3.0 termcolor-1.1.0 werkzeug-1.0.1 wrapt-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Import images

# %%
import pathlib
data_dir = pathlib.Path("./pasta_images")
image_count = len(list(data_dir.glob('*/*')))
print(f'{image_count} images were loaded')
# Out:
# 327 images were loaded

# %% [markdown]
# ## Create and prepare the dataset

# %%
batch_size = 32
img_height = 240
img_width = 240

train_data_set = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 327 files belonging to 4 classes.
# Using 229 files for training.

# %%
validation_data_set = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.3,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 327 files belonging to 4 classes.
# Using 98 files for validation.

# %%
class_names = train_data_set.class_names
print(class_names)
# Out:
# ['gnocchi', 'penne', 'rotini', 'spaghetti']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_data_set.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ## Model creation

# %%
num_classes = len(class_names)

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_6 (Rescaling)      (None, 240, 240, 3)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 240, 240, 16)      448
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 120, 120, 16)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 120, 120, 32)      4640
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 60, 60, 64)        18496
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               7372928
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 7,397,028
# Trainable params: 7,397,028
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
epochs=15
history = model.fit(
  train_data_set,
  validation_data=validation_data_set,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 9s 1s/step - loss: 2.2612 - accuracy: 0.3057 - val_loss: 1.4121 - val_accuracy: 0.2041
# Epoch 2/15
# 8/8 [==============================] - 10s 1s/step - loss: 1.3684 - accuracy: 0.3057 - val_loss: 1.3758 - val_accuracy: 0.3367
# Epoch 3/15
# 8/8 [==============================] - 9s 1s/step - loss: 1.3295 - accuracy: 0.4192 - val_loss: 1.3498 - val_accuracy: 0.4082
# Epoch 4/15
# 8/8 [==============================] - 9s 1s/step - loss: 1.2157 - accuracy: 0.4847 - val_loss: 1.3246 - val_accuracy: 0.3367
# Epoch 5/15
# 8/8 [==============================] - 11s 1s/step - loss: 1.0445 - accuracy: 0.6026 - val_loss: 1.8244 - val_accuracy: 0.3265
# Epoch 6/15
# 8/8 [==============================] - 11s 1s/step - loss: 0.9956 - accuracy: 0.6157 - val_loss: 1.4097 - val_accuracy: 0.4082
# Epoch 7/15
# 8/8 [==============================] - 12s 1s/step - loss: 0.8098 - accuracy: 0.7031 - val_loss: 1.2996 - val_accuracy: 0.3878
# Epoch 8/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.7052 - accuracy: 0.7467 - val_loss: 1.5102 - val_accuracy: 0.3163
# Epoch 9/15
# 8/8 [==============================] - 12s 1s/step - loss: 0.5516 - accuracy: 0.8559 - val_loss: 1.4380 - val_accuracy: 0.4184
# Epoch 10/15
# 8/8 [==============================] - 10s 1s/step - loss: 0.3934 - accuracy: 0.8865 - val_loss: 1.9450 - val_accuracy: 0.4082
# Epoch 11/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.4253 - accuracy: 0.8515 - val_loss: 1.5770 - val_accuracy: 0.3571
# Epoch 12/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.2432 - accuracy: 0.9694 - val_loss: 1.7352 - val_accuracy: 0.4082
# Epoch 13/15
# 8/8 [==============================] - 11s 1s/step - loss: 0.1361 - accuracy: 0.9782 - val_loss: 1.9481 - val_accuracy: 0.3571
# Epoch 14/15
# 8/8 [==============================] - 12s 1s/step - loss: 0.0555 - accuracy: 0.9956 - val_loss: 2.6780 - val_accuracy: 0.3878
# Epoch 15/15
# 8/8 [==============================] - 12s 2s/step - loss: 0.0322 - accuracy: 0.9956 - val_loss: 2.6549 - val_accuracy: 0.3469

# %% [markdown]
# ## Visualize

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Conclusion
#
# Both the training accuracy and the validation loss are increasing --> OVERFITTING!
#
# Validation accuracy is not improving and has an overall bad result between 0.3 and 0.4.

# %% [markdown]
# ## Next Step: Add more training data with flip, rotation and zoom

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_8 (Sequential)    (None, 240, 240, 3)       0
# _________________________________________________________________
# rescaling_9 (Rescaling)      (None, 240, 240, 3)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 240, 240, 16)      448
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 120, 120, 16)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 120, 120, 32)      4640
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 60, 60, 64)        18496
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               7372928
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 7,397,028
# Trainable params: 7,397,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10
history = model.fit(
  train_data_set,
  validation_data=validation_data_set,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 6s 706ms/step - loss: 3.0223 - accuracy: 0.2227 - val_loss: 1.3793 - val_accuracy: 0.2755
# Epoch 2/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.3874 - accuracy: 0.2926 - val_loss: 1.4009 - val_accuracy: 0.2449
# Epoch 3/10
# 8/8 [==============================] - 11s 1s/step - loss: 1.3798 - accuracy: 0.3013 - val_loss: 1.3936 - val_accuracy: 0.1735
# Epoch 4/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.3674 - accuracy: 0.3188 - val_loss: 1.4040 - val_accuracy: 0.2347
# Epoch 5/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.3499 - accuracy: 0.3188 - val_loss: 1.3952 - val_accuracy: 0.2653
# Epoch 6/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.3373 - accuracy: 0.3581 - val_loss: 1.4015 - val_accuracy: 0.3265
# Epoch 7/10
# 8/8 [==============================] - 11s 1s/step - loss: 1.3310 - accuracy: 0.3319 - val_loss: 1.3678 - val_accuracy: 0.2551
# Epoch 8/10
# 8/8 [==============================] - 12s 1s/step - loss: 1.2760 - accuracy: 0.3930 - val_loss: 1.3534 - val_accuracy: 0.4286
# Epoch 9/10
# 8/8 [==============================] - 11s 1s/step - loss: 1.2233 - accuracy: 0.4716 - val_loss: 1.2877 - val_accuracy: 0.4490
# Epoch 10/10
# 8/8 [==============================] - 15s 2s/step - loss: 1.1915 - accuracy: 0.4629 - val_loss: 1.2943 - val_accuracy: 0.4592

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Conclusion
#
# Validation loss is not increasing and the overall accuracy is still increasing. We try to train the model again with more epochs.

# %%
epochs = 10
history = model.fit(
  train_data_set,
  validation_data=validation_data_set,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 5s 649ms/step - loss: 1.1293 - accuracy: 0.4803 - val_loss: 1.4164 - val_accuracy: 0.4490
# Epoch 2/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.1996 - accuracy: 0.4454 - val_loss: 1.3281 - val_accuracy: 0.4388
# Epoch 3/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.1109 - accuracy: 0.5240 - val_loss: 1.3988 - val_accuracy: 0.4082
# Epoch 4/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.0684 - accuracy: 0.5502 - val_loss: 1.5110 - val_accuracy: 0.4286
# Epoch 5/10
# 8/8 [==============================] - 12s 2s/step - loss: 1.1515 - accuracy: 0.4803 - val_loss: 1.3980 - val_accuracy: 0.4082
# Epoch 6/10
# 8/8 [==============================] - 15s 2s/step - loss: 1.0721 - accuracy: 0.5415 - val_loss: 1.4604 - val_accuracy: 0.4286
# Epoch 7/10
# 8/8 [==============================] - 15s 2s/step - loss: 1.0292 - accuracy: 0.5546 - val_loss: 1.4439 - val_accuracy: 0.4286
# Epoch 8/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.9971 - accuracy: 0.5633 - val_loss: 1.5502 - val_accuracy: 0.3878
# Epoch 9/10
# 8/8 [==============================] - 14s 2s/step - loss: 1.0063 - accuracy: 0.5371 - val_loss: 1.5979 - val_accuracy: 0.4082
# Epoch 10/10
# 8/8 [==============================] - 12s 2s/step - loss: 0.9205 - accuracy: 0.6550 - val_loss: 1.5500 - val_accuracy: 0.4388

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Conclusion
#
# Overfitting again!

# %% [markdown]
# ## Next Step: Add a dropout of 20 %

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_12 (Sequential)   (None, 240, 240, 3)       0
# _________________________________________________________________
# rescaling_11 (Rescaling)     (None, 240, 240, 3)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 240, 240, 16)      448
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 120, 120, 16)      0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 120, 120, 32)      4640
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 60, 60, 64)        18496
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               7372928
# _________________________________________________________________
# dense_19 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 7,397,028
# Trainable params: 7,397,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10
history = model.fit(
  train_data_set,
  validation_data=validation_data_set,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 6s 733ms/step - loss: 3.2029 - accuracy: 0.2183 - val_loss: 1.3888 - val_accuracy: 0.2755
# Epoch 2/10
# 8/8 [==============================] - 7s 911ms/step - loss: 1.3864 - accuracy: 0.2052 - val_loss: 1.3884 - val_accuracy: 0.2449
# Epoch 3/10
# 8/8 [==============================] - 9s 1s/step - loss: 1.3861 - accuracy: 0.2926 - val_loss: 1.3846 - val_accuracy: 0.2755
# Epoch 4/10
# 8/8 [==============================] - 11s 1s/step - loss: 1.3654 - accuracy: 0.3144 - val_loss: 1.4676 - val_accuracy: 0.2041
# Epoch 5/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.3744 - accuracy: 0.3362 - val_loss: 1.3822 - val_accuracy: 0.3163
# Epoch 6/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.3833 - accuracy: 0.3013 - val_loss: 1.3853 - val_accuracy: 0.2449
# Epoch 7/10
# 8/8 [==============================] - 21s 3s/step - loss: 1.3844 - accuracy: 0.3057 - val_loss: 1.3843 - val_accuracy: 0.2449
# Epoch 8/10
# 8/8 [==============================] - 12s 2s/step - loss: 1.3809 - accuracy: 0.2926 - val_loss: 1.3836 - val_accuracy: 0.2449
# Epoch 9/10
# 8/8 [==============================] - 11s 1s/step - loss: 1.3711 - accuracy: 0.3013 - val_loss: 1.4476 - val_accuracy: 0.2347
# Epoch 10/10
# 8/8 [==============================] - 13s 2s/step - loss: 1.3305 - accuracy: 0.3624 - val_loss: 1.3509 - val_accuracy: 0.2653

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Conclusion
#
# We have no idea what we are doing!

# %% [markdown]
# ## Next Step: Dropout 10% and remove 1 Layers (conv2D and maxpooling)

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.1),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_14 (Sequential)   (None, 240, 240, 3)       0
# _________________________________________________________________
# rescaling_12 (Rescaling)     (None, 240, 240, 3)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 240, 240, 16)      448
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 120, 120, 16)      0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 120, 120, 32)      4640
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 60, 60, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 60, 32)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 115200)            0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               14745728
# _________________________________________________________________
# dense_21 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 14,751,332
# Trainable params: 14,751,332
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10
history = model.fit(
  train_data_set,
  validation_data=validation_data_set,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 8s 1s/step - loss: 16.6214 - accuracy: 0.2402 - val_loss: 6.7493 - val_accuracy: 0.2551
# Epoch 2/10
# 8/8 [==============================] - 8s 983ms/step - loss: 2.9162 - accuracy: 0.3100 - val_loss: 1.3808 - val_accuracy: 0.2857
# Epoch 3/10
# 8/8 [==============================] - 8s 965ms/step - loss: 1.3958 - accuracy: 0.2271 - val_loss: 1.3763 - val_accuracy: 0.2653
# Epoch 4/10
# 8/8 [==============================] - 11s 1s/step - loss: 1.3757 - accuracy: 0.2926 - val_loss: 1.3705 - val_accuracy: 0.2143
# Epoch 5/10
# 8/8 [==============================] - 9s 1s/step - loss: 1.3641 - accuracy: 0.3319 - val_loss: 1.3691 - val_accuracy: 0.2143
# Epoch 6/10
# 8/8 [==============================] - 11s 1s/step - loss: 1.3465 - accuracy: 0.3799 - val_loss: 1.3754 - val_accuracy: 0.2857
# Epoch 7/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.3107 - accuracy: 0.3144 - val_loss: 1.3887 - val_accuracy: 0.3061
# Epoch 8/10
# 8/8 [==============================] - 9s 1s/step - loss: 1.2854 - accuracy: 0.3493 - val_loss: 1.3699 - val_accuracy: 0.3061
# Epoch 9/10
# 8/8 [==============================] - 12s 1s/step - loss: 1.2686 - accuracy: 0.3974 - val_loss: 1.3339 - val_accuracy: 0.3878
# Epoch 10/10
# 8/8 [==============================] - 10s 1s/step - loss: 1.2463 - accuracy: 0.4498 - val_loss: 1.3490 - val_accuracy: 0.3673

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Next steps : höhere Learning Rate
